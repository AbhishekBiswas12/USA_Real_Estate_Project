# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('realtor-data.csv')
df
# Out:
#           status     price  bed  bath  acre_lot  \
# 0       for_sale  105000.0  3.0   2.0      0.12
# 1       for_sale   80000.0  4.0   2.0      0.08
# 2       for_sale   67000.0  2.0   1.0      0.15
# 3       for_sale  145000.0  4.0   2.0      0.10
# 4       for_sale   65000.0  6.0   2.0      0.05
# ...          ...       ...  ...   ...       ...
# 923154  for_sale  445000.0  1.0   2.0      0.99
# 923155  for_sale  418000.0  4.0   2.0      0.40
# 923156  for_sale  469000.0  4.0   2.0      0.18
# 923157  for_sale  825000.0  5.0   5.0      0.79
# 923158  for_sale   88000.0  NaN   NaN     35.00
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...

# %%
df.columns
# Out:
# Index(['status', 'price', 'bed', 'bath', 'acre_lot', 'full_address', 'street',
#        'city', 'state', 'zip_code', 'house_size', 'sold_date'],
#       dtype='object')

# %% [markdown]
# ### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923159 entries, 0 to 923158
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        923159 non-null  object
#  1   price         923088 non-null  float64
#  2   bed           791456 non-null  float64
#  3   bath          807967 non-null  float64
#  4   acre_lot      649536 non-null  float64
#  5   full_address  923159 non-null  object
#  6   street        921021 non-null  object
#  7   city          923085 non-null  object
#  8   state         923159 non-null  object
#  9   zip_code      922954 non-null  float64
#  10  house_size    625316 non-null  float64
#  11  sold_date     456396 non-null  object
# dtypes: float64(6), object(6)
# memory usage: 84.5+ MB

# %%
df.describe()
# Out:
#               price            bed           bath       acre_lot  \
# count  9.230880e+05  791456.000000  807967.000000  649536.000000
# mean   8.841225e+05       3.330352       2.488164      17.075888
# std    2.623745e+06       2.070402       1.940057     962.322866
# min    0.000000e+00       1.000000       1.000000       0.000000
# 25%    2.690000e+05       2.000000       1.000000       0.110000
# 50%    4.750000e+05       3.000000       2.000000       0.290000
# 75%    8.399000e+05       4.000000       3.000000       1.150000
# max    8.750000e+08     123.000000     198.000000  100000.000000
#
#             zip_code    house_size
# count  922954.000000  6.253160e+05
# mean     6590.061523  2.141644e+03
# std      3818.208203  3.035327e+03
# min       601.000000  1.000000e+02
# 25%      2919.000000  1.130000e+03
# 50%      7004.000000  1.651000e+03
# 75%     10001.000000  2.499000e+03
# max     99999.000000  1.450112e+06

# %%
df.isna().sum()
# Out:
# status               0
# price               71
# bed             131703
# bath            115192
# acre_lot        273623
# full_address         0
# street            2138
# city                74
# state                0
# zip_code           205
# house_size      297843
# sold_date       466763
# dtype: int64

# %% [markdown]
# ### Handling Null values

# %%
x = [i for i in df.columns if df[f"{i}"].isna().sum()>=1]
print("Percentage of NULL Values: ")
for i in x:
    print(i,": {:.2f}".format((df[f"{i}"].isna().sum()*100/len(df))), "%")
# Out:
# Percentage of NULL Values:
# price : 0.01 %
# bed : 14.27 %
# bath : 12.48 %
# acre_lot : 29.64 %
# street : 0.23 %
# city : 0.01 %
# zip_code : 0.02 %
# house_size : 32.26 %
# sold_date : 50.56 %

# %%
df1 = df.drop("sold_date", axis = 1)
df1
# Out:
#           status     price  bed  bath  acre_lot  \
# 0       for_sale  105000.0  3.0   2.0      0.12
# 1       for_sale   80000.0  4.0   2.0      0.08
# 2       for_sale   67000.0  2.0   1.0      0.15
# 3       for_sale  145000.0  4.0   2.0      0.10
# 4       for_sale   65000.0  6.0   2.0      0.05
# ...          ...       ...  ...   ...       ...
# 923154  for_sale  445000.0  1.0   2.0      0.99
# 923155  for_sale  418000.0  4.0   2.0      0.40
# 923156  for_sale  469000.0  4.0   2.0      0.18
# 923157  for_sale  825000.0  5.0   5.0      0.79
# 923158  for_sale   88000.0  NaN   NaN     35.00
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...

# %%
df1['price'] = df1.price.fillna(df1.price.mean())
df1
# Out:
#           status     price  bed  bath  acre_lot  \
# 0       for_sale  105000.0  3.0   2.0      0.12
# 1       for_sale   80000.0  4.0   2.0      0.08
# 2       for_sale   67000.0  2.0   1.0      0.15
# 3       for_sale  145000.0  4.0   2.0      0.10
# 4       for_sale   65000.0  6.0   2.0      0.05
# ...          ...       ...  ...   ...       ...
# 923154  for_sale  445000.0  1.0   2.0      0.99
# 923155  for_sale  418000.0  4.0   2.0      0.40
# 923156  for_sale  469000.0  4.0   2.0      0.18
# 923157  for_sale  825000.0  5.0   5.0      0.79
# 923158  for_sale   88000.0  NaN   NaN     35.00
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...

# %%
df1.isna().sum()
# Out:
# status               0
# price                0
# bed             131703
# bath            115192
# acre_lot        273623
# full_address         0
# street            2138
# city                74
# state                0
# zip_code           205
# house_size      297843
# dtype: int64

# %%
df1.describe()
# Out:
#               price            bed           bath       acre_lot  \
# count  9.231590e+05  791456.000000  807967.000000  649536.000000
# mean   8.841225e+05       3.330352       2.488164      17.075888
# std    2.623644e+06       2.070402       1.940057     962.322866
# min    0.000000e+00       1.000000       1.000000       0.000000
# 25%    2.690000e+05       2.000000       1.000000       0.110000
# 50%    4.750000e+05       3.000000       2.000000       0.290000
# 75%    8.399000e+05       4.000000       3.000000       1.150000
# max    8.750000e+08     123.000000     198.000000  100000.000000
#
#             zip_code    house_size
# count  922954.000000  6.253160e+05
# mean     6590.061523  2.141644e+03
# std      3818.208203  3.035327e+03
# min       601.000000  1.000000e+02
# 25%      2919.000000  1.130000e+03
# 50%      7004.000000  1.651000e+03
# 75%     10001.000000  2.499000e+03
# max     99999.000000  1.450112e+06

# %%
bed_city = {}

for city in df1['city'].unique():
    bed_city[f"{city}"] = 0
    bed_city[f"{city}"] = df1[df1["city"] == city]['bed'].median()

# %%
bed_city
# Out:
# {'Adjuntas': 3.0,
#  'Juana Diaz': 3.0,
#  'Ponce': 3.0,
#  'Mayaguez': 4.0,
#  'San Sebastian': 3.0,
#  'Ciales': 3.0,
#  'Las Marias': 5.0,
#  'Isabela': 3.0,
#  'Lares': 3.0,
#  'Utuado': 3.0,
#  'Yauco': 3.0,
#  'Anasco': 6.0,
#  'Moca': 3.0,
#  'Coamo': 3.0,
#  'Guayanilla': 3.5,
#  'Manati': 3.0,
#  'Villalba': 6.0,
#  'Santa Isabel': 3.0,
#  'Penuelas': 3.0,
#  'Hatillo': 4.0,
#  'Aguada': 3.0,
#  'Rincon': 3.0,
#  'Aguadilla': 4.0,
#  'Maricao': 5.0,
#  'Hormigueros': 4.0,
#  'Guanica': 3.0,
#  'Cabo Rojo': 3.0,
#  'San German': 3.0,
#  'Lajas': 4.0,
#  'Arecibo': 3.0,
#  'Camuy': 3.0,
#  'Morovis': 5.0,
#  'Barceloneta': 3.0,
#  'Quebradillas': 5.0,
#  'Vega Baja': 3.0,
#  'Caguas': 3.0,
#  'Dorado': 3.0,
#  'Toa Baja': 3.0,
#  'Toa Alta': 3.0,
#  'Vega Alta': 3.0,
#  'Corozal': 3.0,
#  'Naranjito': 3.0,
#  'Boqueron': nan,
#  'Carolina': 3.0,
#  'Sabana Grande': 3.0,
#  'Canovanas': 3.0,
#  'Jayuya': 3.0,
#  'Trujillo Alto': 3.0,
#  'Florida': 3.0,
#  'Las Piedras': 3.0,
# ...

# %%
len(df1.city.unique())
# Out:
# 2543
